# %%
import pandas as pd


pct_df = pd.read_csv('./data/pre_corona_pct.csv')
pct_df
# Out:
#         날짜  전자상거래/통신판매      종합소매       자동차     가구/가전     의류/잡화  스포츠/오락/여가  \
# 0   201212    0.027613  0.077909  0.192904 -0.122218 -0.031449  -0.135839
# 1   201301   -0.047579 -0.109930 -0.309056 -0.006880 -0.156039  -0.113972
# 2   201302   -0.138342 -0.063111  0.037585 -0.023821 -0.068648  -0.150124
# 3   201303    0.085685  0.029723  0.223547  0.270387  0.183154   0.355010
# 4   201304    0.045225  0.052395  0.004995 -0.081842 -0.009763   0.028387
# ..     ...         ...       ...       ...       ...       ...        ...
# 80  201908   -0.035341 -0.000307 -0.016113 -0.022230 -0.078643  -0.013531
# 81  201909    0.007732  0.043247 -0.069466 -0.120368  0.053118  -0.056002
# 82  201910    0.075294 -0.049243  0.151562  0.042041  0.175382   0.176650
# 83  201911    0.054219  0.005385  0.060822  0.044813 -0.010022  -0.052854
# 84  201912    0.035942  0.036404  0.079588 -0.039294 -0.025682  -0.092145
#
#          식료품        연료     여행/교통  ...     금융/보험   소비자물가지수    소매판매지수  \
# ...

# %%
book_df = pct_df[["날짜", "서적/문구", "소비자물가지수", "소매판매지수"]]
book_df
# Out:
#         날짜     서적/문구   소비자물가지수    소매판매지수
# 0   201212  0.118333  0.001782  0.023590
# 1   201301 -0.069215  0.005999 -0.086172
# 2   201302 -0.107126  0.003343 -0.048246
# 3   201303  0.471158 -0.000924  0.078341
# 4   201304 -0.204835 -0.001388 -0.018162
# ..     ...       ...       ...       ...
# 80  201908 -0.016262  0.002400  0.009050
# 81  201909 -0.024028  0.003711  0.016143
# 82  201910 -0.033313  0.002475  0.021183
# 83  201911  0.021241 -0.005598  0.040622
# 84  201912  0.121899  0.002392  0.009967
#
# [85 rows x 4 columns]

# %%
# book_df["날짜"] = pd.to_datetime(book_df["날짜"], format='%Y%m')     # 데이터 타입 datetime으로 변경
# book_df["날짜"] = book_df["날짜"].dt.strftime('%Y%m')                 # datetime 형식 설정
# book_df.set_index("날짜", inplace=True)                              # 날짜 컬럼 인덱스 설정

# %%
# book_df[["점수", "소비"]] = "" 
# book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\2324162201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df[["점수", "소비"]] = ""
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\2324162201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df[["점수", "소비"]] = ""
#         날짜     서적/문구   소비자물가지수    소매판매지수 점수 소비
# 0   201212  0.118333  0.001782  0.023590
# 1   201301 -0.069215  0.005999 -0.086172
# 2   201302 -0.107126  0.003343 -0.048246
# ...

# %% [markdown]
# ### 레이블

# %%
# 3월에 점수 1을 준다
# def month_encoding(month):
#     score = ""
#     if month.endswith("03") : score = 1
#     else : score = 0
    # return score

# %%
# book_df["날짜"] = book_df["날짜"].astype(str)
# book_df["점수"] = book_df["날짜"].apply(lambda x: month_encoding(x))
# book_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5276\605068124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["날짜"] = book_df["날짜"].astype(str)
# C:\Users\user\AppData\Local\Temp\ipykernel_5276\605068124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["점수"] = book_df["날짜"].apply(lambda x: month_encoding(x))
#         날짜     서적/문구   소비자물가지수    소매판매지수  점수
# 0   201212  0.118333  0.001782  0.023590   0
# 1   201301 -0.069215  0.005999 -0.086172   0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(16,10))

sns.heatmap(book_df.corr(), annot=True)

plt.show()

# %%
book_df.describe()
# Out:
#                   날짜      서적/문구    소비자물가지수     소매판매지수
# count      85.000000  85.000000  85.000000  85.000000
# mean   201601.858824   0.015444   0.000952   0.003923
# std       204.555276   0.175948   0.003223   0.051923
# min    201212.000000  -0.286140  -0.007443  -0.104563
# 25%    201409.000000  -0.080040  -0.001261  -0.034296
# 50%    201606.000000  -0.024028   0.001091   0.009050
# 75%    201803.000000   0.077957   0.002578   0.032727
# max    201912.000000   0.514840   0.010629   0.162325

# %%
book_df[book_df["소비"]==1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '소비'
#
# ...

# %%
book_df[book_df["소비"]==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '소비'
#
# ...

# %%
pd.set_option('display.max_row', None)

# %%
# import numpy as np

# book_df["소비"] = ""

# for i in range(0, 13):
#     for j in range(12, 85):
#         # 첫 1년
#         if book_df.loc[i,"서적/문구"] > 0: 
#             if book_df.loc[i,"소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
#                 book_df.loc[i,"소비"] = 1
#             elif book_df.loc[i,"소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
#                 if book_df.loc[i,"소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
#                     book_df.loc[i,"소비"] = 1
#                 else:
#                     book_df.loc[i,"소비"] = 0
#             elif book_df.loc[i,"소매판매지수"] < book_df["소매판매지수"].quantile(q=0.25):
#                 book_df.loc[i,"소비"] = 0

#         elif book_df.loc[i, "서적/문구"] <= 0:
#             if book_df.loc[i,"소매판매지수"] <= book_df["소매판매지수"].quantile(q=0.75):
#                 book_df.loc[i,"소비"] = 0
#             elif book_df.loc[i,"소매판매지수"] > book_df["소매판매지수"].quantile(q=0.75):
#                 if book_df.loc[i,"소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
#                     book_df.loc[i,"소비"] = 0
#                 else:
#                     book_df.loc[i,"소비"] = 1

#         # 첫 1년 이후
#         if book_df["서적/문구"].loc[j] > 0:
#             if book_df["서적/문구"].loc[j] > book_df["서적/문구"].loc[j-12]:
#                 book_df.loc[j,"소비"] = 1
#             elif book_df["서적/문구"].loc[j] <= book_df["서적/문구"].loc[j-12]:
#                 if book_df.loc[j,"소매판매지수"] > book_df["소매판매지수"].quantile(q=0.25): 
#                     if book_df.loc[j,"소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.75):
#                         book_df.loc[j,"소비"] = 1
#                     else:
#                         book_df.loc[j,"소비"] = 0
#                 else:
#                     book_df.loc[j,"소비"] = 0
            
#         elif book_df["서적/문구"].loc[j] <= 0:
#             if book_df["서적/문구"].loc[j] <= book_df["서적/문구"].loc[j-12]:
#                 if book_df.loc[j,"소매판매지수"] <= book_df["소매판매지수"].quantile(q=0.75): 
#                     book_df.loc[j, "소비"] = 0
#                 elif book_df.loc[j,"소매판매지수"] > book_df["소매판매지수"].quantile(q=0.75):
#                     if book_df.loc[j,"소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
#                         book_df.loc[j,"소비"] = 0
#                     else:
#                         book_df.loc[j,"소비"] = 1
#             elif book_df["서적/문구"].loc[j] > book_df["서적/문구"].loc[j-12]:
#                 if book_df.loc[j,"소매판매지수"] > book_df["소매판매지수"].quantile(q=0.75):
#                     book_df.loc[j,"소비"] = 1
#                 else:
#                     book_df.loc[j,"소비"] = 0
            
# book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_11224\2132782078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["날짜"] = book_df["날짜"].astype(str)
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_11224\2132782078.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["소비"] = ""
#         날짜     서적/문구   소비자물가지수    소매판매지수 소비
# 0   201212  0.118333  0.001782  0.023590  1
# 1   201301 -0.069215  0.005999 -0.086172  0
# 2   201302 -0.107126  0.003343 -0.048246  0
# ...

# %%
book_df.describe()
# Out:
#            서적/문구    소비자물가지수     소매판매지수
# count  85.000000  85.000000  85.000000
# mean    0.015444   0.000952   0.003923
# std     0.175948   0.003223   0.051923
# min    -0.286140  -0.007443  -0.104563
# 25%    -0.080040  -0.001261  -0.034296
# 50%    -0.024028   0.001091   0.009050
# 75%     0.077957   0.002578   0.032727
# max     0.514840   0.010629   0.162325

# %%
book_df[book_df["날짜"].str.endswith("12")].describe()
# Out:
#           서적/문구   소비자물가지수    소매판매지수
# count  8.000000  8.000000  8.000000
# mean   0.166924  0.001193  0.015728
# std    0.051117  0.002205  0.020286
# min    0.118333 -0.003443 -0.018261
# 25%    0.137049  0.000794  0.007905
# 50%    0.161806  0.001498  0.015703
# 75%    0.171282  0.002543  0.024042
# max    0.281181  0.003606  0.052000

# %% [markdown]
# ### 월별 등락률 평균

# %%
# 서적/문구 데이터프레임 복사
month_df = book_df.copy()
month_df = month_df[["날짜", "서적/문구"]]
month_df.head()
# Out:
#        날짜     서적/문구
# 0  201212  0.118333
# 1  201301 -0.069215
# 2  201302 -0.107126
# 3  201303  0.471158
# 4  201304 -0.204835

# %%
month_df.describe()
# Out:
#                   날짜      서적/문구
# count      85.000000  85.000000
# mean   201601.858824   0.015444
# std       204.555276   0.175948
# min    201212.000000  -0.286140
# 25%    201409.000000  -0.080040
# 50%    201606.000000  -0.024028
# 75%    201803.000000   0.077957
# max    201912.000000   0.514840

# %%
# string 타입으로 변환
month_df["날짜"] = month_df["날짜"].astype(str)

# %%
# 동월 전체 평균
month_df["서적/문구"][month_df["날짜"].str.endswith("12")].mean()
# Out:
# 0.16692383500859184

# %%
month_df.head()
# Out:
#        날짜     서적/문구
# 0  201212  0.118333
# 1  201301 -0.069215
# 2  201302 -0.107126
# 3  201303  0.471158
# 4  201304 -0.204835

# %%
pre_mean = month_df["서적/문구"].mean()

# %%
# 각 동월 전체 평균 리스트 저장

month_list = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]
month_mean = []
for i in month_list:
    print(month_df["서적/문구"][month_df["날짜"].str.endswith(i)].mean())
    month_mean.append(month_df["서적/문구"][month_df["날짜"].str.endswith(i)].mean())
    
month_mean
# Out:
# -0.09377506840603304
# -0.08125907698439293
# 0.45989723679854866
# -0.2637166991734026
# -0.02965591246715889
# -0.06021902317911464
# 0.13937164065191374
# -0.06001337329946312
# 0.01768928819256827
# -0.04944342323545781
# 0.01788438623691117
# 0.16692383500859184
# [-0.09377506840603304,
#  -0.08125907698439293,
#  0.45989723679854866,
#  -0.2637166991734026,
#  -0.02965591246715889,
#  -0.06021902317911464,
#  0.13937164065191374,
#  -0.06001337329946312,
#  0.01768928819256827,
#  -0.04944342323545781,
#  0.01788438623691117,
#  0.16692383500859184]

# %%
# "동월_평균_등락률" 컬럼 생성 및 값 저장

month_df["동월_평균_등락률"] = ""
for i in month_list:
        month_df["동월_평균_등락률"][month_df["날짜"].str.endswith(i)]  = month_df["서적/문구"][month_df["날짜"].str.endswith(i)].mean()
month_df.head(20)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8412\1461874661.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_df["동월_평균_등락률"][month_df["날짜"].str.endswith(i)]  = month_df["서적/문구"][month_df["날짜"].str.endswith(i)].mean()
#         날짜     서적/문구 동월_평균_등락률
# 0   201212  0.118333  0.166924
# 1   201301 -0.069215 -0.093775
# 2   201302 -0.107126 -0.081259
# 3   201303  0.471158  0.459897
# 4   201304 -0.204835 -0.263717
# 5   201305 -0.104216 -0.029656
# 6   201306 -0.079599 -0.060219
# 7   201307  0.160407  0.139372
# 8   201308 -0.088365 -0.060013
# 9   201309  0.014355  0.017689
# 10  201310 -0.011677 -0.049443
# 11  201311  0.014116  0.017884
# 12  201312  0.168430  0.166924
# 13  201401 -0.103812 -0.093775
# 14  201402 -0.081359 -0.081259
# 15  201403  0.459274  0.459897
# ...

# %%
len(month_df)
# Out:
# 85

# %%
# "전체_평균_대비" 컬럼 생성 및 값 저장

month_df["전체_평균_대비"] = ""

# 동월 평균 등락률이 전체 평균 보다 높거나 같으면 1, 낮으면 0
for i in range(0, 85):
    if month_df.loc[i, "동월_평균_등락률"] >= pre_mean:
        month_df.loc[i, "전체_평균_대비"] = 1
    else:
        month_df.loc[i, "전체_평균_대비"] = 0

month_df.tail(20)
# Out:
#         날짜     서적/문구 동월_평균_등락률 전체_평균_대비
# 65  201805  0.023894 -0.029656        0
# 66  201806 -0.052572 -0.060219        0
# 67  201807  0.100549  0.139372        1
# 68  201808 -0.031346 -0.060013        0
# 69  201809  0.009911  0.017689        1
# 70  201810 -0.052978 -0.049443        0
# 71  201811  0.018729  0.017884        1
# 72  201812  0.159593  0.166924        1
# 73  201901 -0.041497 -0.093775        0
# 74  201902 -0.106819 -0.081259        0
# 75  201903  0.429745  0.459897        1
# 76  201904 -0.265850 -0.263717        0
# 77  201905  0.005815 -0.029656        0
# 78  201906 -0.044019 -0.060219        0
# 79  201907  0.077752  0.139372        1
# 80  201908 -0.016262 -0.060013        0
# 81  201909 -0.024028  0.017689        1
# 82  201910 -0.033313 -0.049443        0
# 83  201911  0.021241  0.017884        1
# 84  201912  0.121899  0.166924        1

# %%
book_df.to_csv('./data/up_or_down.csv')

# %% [markdown]
# #### 서적/문구 데이터 프레임에 컬럼 추가

# %%
book_df["동월_평균_등락률"] = month_df["동월_평균_등락률"]
book_df["전체_평균_대비"] = month_df["전체_평균_대비"]
book_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8412\2660682954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["동월_평균_등락률"] = month_df["동월_평균_등락률"]
# C:\Users\user\AppData\Local\Temp\ipykernel_8412\2660682954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["전체_평균_대비"] = month_df["전체_평균_대비"]
#        날짜     서적/문구   소비자물가지수    소매판매지수 동월_평균_등락률 전체_평균_대비
# 0  201212  0.118333  0.001782  0.023590  0.166924        1
# ...

# %%
book_df.describe()
# Out:
#                   날짜      서적/문구    소비자물가지수     소매판매지수
# count      85.000000  85.000000  85.000000  85.000000
# mean   201601.858824   0.015444   0.000952   0.003923
# std       204.555276   0.175948   0.003223   0.051923
# min    201212.000000  -0.286140  -0.007443  -0.104563
# 25%    201409.000000  -0.080040  -0.001261  -0.034296
# 50%    201606.000000  -0.024028   0.001091   0.009050
# 75%    201803.000000   0.077957   0.002578   0.032727
# max    201912.000000   0.514840   0.010629   0.162325

# %%
for i in range(12, 85):
    if book_df.loc[i, "서적/문구"] > book_df.loc[i-12, "서적/문구"]:
        book_df.loc[i, "전년_동월_대비"] = 1
    else:
        book_df.loc[i, "전년_동월_대비"] = 0
# book_df["전년_동월_대비"] = book_df["전년_동월_대비"].astype(int)
book_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8412\3226781203.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df.loc[i, "전년_동월_대비"] = 1
#         날짜     서적/문구   소비자물가지수    소매판매지수 동월_평균_등락률 전체_평균_대비  전년_동월_대비
# 0   201212  0.118333  0.001782  0.023590  0.166924        1       NaN
# 1   201301 -0.069215  0.005999 -0.086172 -0.093775        0       NaN
# 2   201302 -0.107126  0.003343 -0.048246 -0.081259        0       NaN
# 3   201303  0.471158 -0.000924  0.078341  0.459897        1       NaN
# 4   201304 -0.204835 -0.001388 -0.018162 -0.263717        0       NaN
# ..     ...       ...       ...       ...       ...      ...       ...
# 80  201908 -0.016262  0.002400  0.009050 -0.060013        0       1.0
# ...

# %%
import numpy as np

book_df["날짜"] = book_df["날짜"].astype(str)
book_df["소비"] = ""

for i in range(0, 13):
    for j in range(12, 85):
        # 첫 1년
        # 전체 평균 등락률 보다 높다
        if book_df.loc[i,"전체_평균_대비"] == 1:
            if book_df.loc[i, "날짜"].endswith("03") or book_df.loc[i, "날짜"].endswith("07") or book_df.loc[i, "날짜"].endswith("12"):
                if book_df.loc[i,"서적/문구"] >= book_df["서적/문구"].quantile(q=0.75):
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                            book_df.loc[i, "소비"] = 1
                    elif book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                            
                elif book_df.loc[i,"서적/문구"] < book_df["서적/문구"].quantile(q=0.75):
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5): 
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 1
                    elif book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
            elif book_df.loc[i, "날짜"].endswith("01") or book_df.loc[i, "날짜"].endswith("02") or book_df.loc[i, "날짜"].endswith("04")\
            or book_df.loc[i, "날짜"].endswith("05") or book_df.loc[i, "날짜"].endswith("06") or book_df.loc[i, "날짜"].endswith("08")\
            or book_df.loc[i, "날짜"].endswith("09") or book_df.loc[i, "날짜"].endswith("10") or book_df.loc[i, "날짜"].endswith("11"):
                if book_df.loc[i,"서적/문구"] <= book_df["서적/문구"].quantile(q=.5):
                    if book_df.loc[i, "소비자물가지수"] >= book_df["소비자물가지수"].quantile(q=0.25):
                        if book_df.loc[i, "소매판매지수"] < book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 0
                        else:
                            book_df.loc[i, "소비"] = 1
                    elif book_df.loc[i, "소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.25):
                        if book_df.loc[i, "소매판매지수"] < book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 0
                        else:
                            book_df.loc[i, "소비"] = 1
                            
                elif book_df.loc[i,"서적/문구"] > book_df["서적/문구"].quantile(q=.5):
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5): 
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 1
                    elif book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
        
        # 전체 평균 등락률 보다 낮다
        elif book_df.loc[i,"전체_평균_대비"] == 0:
            if book_df.loc[i, "날짜"].endswith("01") or book_df.loc[i, "날짜"].endswith("02") or book_df.loc[i, "날짜"].endswith("04")\
            or book_df.loc[i, "날짜"].endswith("05") or book_df.loc[i, "날짜"].endswith("06") or book_df.loc[i, "날짜"].endswith("08")\
            or book_df.loc[i, "날짜"].endswith("09") or book_df.loc[i, "날짜"].endswith("10") or book_df.loc[i, "날짜"].endswith("11"):
                if book_df.loc[i,"서적/문구"] <= book_df["서적/문구"].quantile(q=.5):
                    if book_df.loc[i, "소비자물가지수"] >= book_df["소비자물가지수"].quantile(q=0.25):
                        if book_df.loc[i, "소매판매지수"] < book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 0
                        else:
                            book_df.loc[i, "소비"] = 1
                    elif book_df.loc[i, "소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.25):
                        if book_df.loc[i, "소매판매지수"] <= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 0
                        else:
                            book_df.loc[i, "소비"] = 1
                            
                elif book_df.loc[i,"서적/문구"] > book_df["서적/문구"].quantile(q=.5):
                    if book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.25): 
                        if book_df.loc[i, "소매판매지수"] < book_df["소매판매지수"].quantile(q=0.75):
                            book_df.loc[i, "소비"] = 0
                    elif book_df.loc[i, "소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.75):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
        
        # 1년 이후
        if book_df.loc[j, "전체_평균_대비"] == 1:
            if book_df.loc[j, "날짜"].endswith("03") or book_df.loc[j, "날짜"].endswith("07") or book_df.loc[j, "날짜"].endswith("12"):
                if book_df.loc[j, "전년_동월_대비"] == 1:
                    if book_df.loc[j, "서적/문구"] >= book_df["서적/문구"].quantile(q=0.75):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                                book_df.loc[j, "소비"] = 1
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                    
                    elif book_df.loc[j,"서적/문구"] < book_df["서적/문구"].quantile(q=0.75):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5): 
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                
                elif book_df.loc[j, "전년_동월_대비"] == 0:
                    if book_df.loc[j, "서적/문구"] >= book_df["서적/문구"].quantile(q=0.75):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        if book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                    
                    elif book_df.loc[j, "서적/문구"] < book_df["서적/문구"].quantile(q=0.75):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                                
            elif book_df.loc[j, "날짜"].endswith("01") or book_df.loc[j, "날짜"].endswith("02") or book_df.loc[j, "날짜"].endswith("04")\
            or book_df.loc[j, "날짜"].endswith("05") or book_df.loc[j, "날짜"].endswith("06") or book_df.loc[j, "날짜"].endswith("08")\
            or book_df.loc[j, "날짜"].endswith("09") or book_df.loc[j, "날짜"].endswith("10") or book_df.loc[j, "날짜"].endswith("11"):
                if book_df.loc[j, "전년_동월_대비"] == 1:
                    if book_df.loc[j,"서적/문구"] > book_df["서적/문구"].quantile(q=.5):
                        if book_df.loc[j, "소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.75):
                            if book_df.loc[j, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.25):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                            if book_df.loc[j, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                                
                    elif book_df.loc[j,"서적/문구"] <= book_df["서적/문구"].quantile(q=.5):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5): 
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                                
                if book_df.loc[j, "전년_동월_대비"] == 0:
                    if book_df.loc[j,"서적/문구"] > book_df["서적/문구"].quantile(q=.5):
                        if book_df.loc[j, "소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                                
                    elif book_df.loc[j,"서적/문구"] <= book_df["서적/문구"].quantile(q=.5):
                        if book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5): 
                            if book_df.loc[j, "소매판매지수"] < book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 0
                            else:
                                book_df.loc[j, "소비"] = 1
                        elif book_df.loc[j, "소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] < book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 0
                            else:
                                book_df.loc[j, "소비"] = 1
                                
        elif book_df.loc[j, "전체_평균_대비"] == 0:
            if book_df.loc[j, "날짜"].endswith("03") or book_df.loc[j, "날짜"].endswith("07") or book_df.loc[j, "날짜"].endswith("12"):
                if book_df.loc[j, "전년_동월_대비"] == 1:
                    if book_df.loc[j, "서적/문구"] >= book_df["서적/문구"].quantile(q=0.75):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                                book_df.loc[j, "소비"] = 1
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                                
                    elif book_df.loc[j,"서적/문구"] < book_df["서적/문구"].quantile(q=0.75):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5): 
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                
                elif book_df.loc[j, "전년_동월_대비"] == 0:
                    if book_df.loc[j, "서적/문구"] >= book_df["서적/문구"].quantile(q=0.75):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        if book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                    
                    elif book_df.loc[j, "서적/문구"] < book_df["서적/문구"].quantile(q=0.75):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        
            elif book_df.loc[j, "날짜"].endswith("01") or book_df.loc[j, "날짜"].endswith("02") or book_df.loc[j, "날짜"].endswith("04")\
            or book_df.loc[j, "날짜"].endswith("05") or book_df.loc[j, "날짜"].endswith("06") or book_df.loc[j, "날짜"].endswith("08")\
            or book_df.loc[j, "날짜"].endswith("09") or book_df.loc[j, "날짜"].endswith("10") or book_df.loc[j, "날짜"].endswith("11"):
                if book_df.loc[j, "전년_동월_대비"] == 1:
                    if book_df.loc[j,"서적/문구"] > book_df["서적/문구"].quantile(q=.5):
                        if book_df.loc[j, "소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.25):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        elif book_df.loc[j, "소비자물가지수"] >= book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                                
                    elif book_df.loc[j,"서적/문구"] <= book_df["서적/문구"].quantile(q=.5):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.25): 
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.25):
                            if book_df.loc[j, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                                
                if book_df.loc[j, "전년_동월_대비"] == 0:
                    if book_df.loc[j,"서적/문구"] > book_df["서적/문구"].quantile(q=.5):
                        if book_df.loc[j, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.25):
                            if book_df.loc[j, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                        elif book_df.loc[j, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] > book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 1
                            else:
                                book_df.loc[j, "소비"] = 0
                                
                    elif book_df.loc[j,"서적/문구"] <= book_df["서적/문구"].quantile(q=.5):
                        if book_df.loc[j, "소비자물가지수"] >= book_df["소비자물가지수"].quantile(q=0.5): 
                            if book_df.loc[j, "소매판매지수"] < book_df["소매판매지수"].quantile(q=0.5):
                                book_df.loc[j, "소비"] = 0
                            else:
                                book_df.loc[j, "소비"] = 1
                        elif book_df.loc[j, "소비자물가지수"] < book_df["소비자물가지수"].quantile(q=0.5):
                            if book_df.loc[j, "소매판매지수"] < book_df["소매판매지수"].quantile(q=0.75):
                                book_df.loc[j, "소비"] = 0
                            else:
                                book_df.loc[j, "소비"] = 1
            

book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_11224\336874490.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["날짜"] = book_df["날짜"].astype(str)
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_11224\336874490.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["소비"] = ""
#         날짜     서적/문구   소비자물가지수    소매판매지수 동월_평균_등락률 전체_평균_대비 소비  전년_동월_대비
# 0   201212  0.118333  0.001782  0.023590  0.166924        1  1       NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16,10))
sns.regplot(book_df['날짜'], book_df["서적/문구"])
plt.show()
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# d:\project1_dajopay\classification.ipynb 셀 34 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/project1_dajopay/classification.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/d%3A/project1_dajopay/classification.ipynb#X45sZmlsZQ%3D%3D?line=3'>4</a> plt.figure(figsize=(16,10))
# ...

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

book_df["서적/문구"].plot(kind='line', label="서적/문구", ax=ax1)
ax1.set_ylabel("서적/문구")
plt.legend(loc="upper left")  

ax2 = ax1.twinx()
book_df["소매판매지수"].plot(kind='line', marker='o' , color="r", label="소매판매지수", ax=ax2)

ax2.set_ylabel("소매판매지수")

plt.legend(loc="upper right")  
plt.show()

# %%
book_df["월"] = book_df["날짜"].str.slice(4, 6)
book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_11224\4038666019.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["월"] = book_df["날짜"].str.slice(4, 6)
#         날짜     서적/문구   소비자물가지수    소매판매지수 동월_평균_등락률 전체_평균_대비 소비  전년_동월_대비   월
# 0   201212  0.118333  0.001782  0.023590  0.166924        1  1       NaN  12
# 1   201301 -0.069215  0.005999 -0.086172 -0.093775        0          NaN  01
# 2   201302 -0.107126  0.003343 -0.048246 -0.081259        0          NaN  02
# 3   201303  0.471158 -0.000924  0.078341  0.459897        1  1       NaN  03
# 4   201304 -0.204835 -0.001388 -0.018162 -0.263717        0  1       NaN  04
# 5   201305 -0.104216  0.000000  0.052231 -0.029656        0  0       NaN  05
# ...

# %%
for i in range(0, 13):
    book_df.loc[i, "전년_동월_대비"] = book_df.loc[i, "전체_평균_대비"]
book_df
# Out:
#         날짜     서적/문구   소비자물가지수    소매판매지수 동월_평균_등락률 전체_평균_대비 소비  전년_동월_대비   월
# 0   201212  0.118333  0.001782  0.023590  0.166924        1          1.0  12
# 1   201301 -0.069215  0.005999 -0.086172 -0.093775        0          0.0  01
# 2   201302 -0.107126  0.003343 -0.048246 -0.081259        0          0.0  02
# 3   201303  0.471158 -0.000924  0.078341  0.459897        1          1.0  03
# 4   201304 -0.204835 -0.001388 -0.018162 -0.263717        0          0.0  04
# 5   201305 -0.104216  0.000000  0.052231 -0.029656        0          0.0  05
# 6   201306 -0.079599 -0.001217 -0.036194 -0.060219        0          0.0  06
# 7   201307  0.160407  0.002146  0.022532  0.139372        1          1.0  07
# 8   201308 -0.088365  0.003541 -0.044071 -0.060013        0          0.0  08
# 9   201309  0.014355  0.001941  0.031833  0.017689        1          1.0  09
# 10  201310 -0.011677 -0.003051  0.032979 -0.049443        0          0.0  10
# ...

# %%
book_df["날짜"] = book_df["날짜"].astype(str)
book_df["소비"] = ""

for i in book_df.index:
    if book_df.loc[i, "월"] == "03" or book_df.loc[i, "월"] == "07" or book_df.loc[i, "월"] == "12": 
        if book_df.loc[i, "전체_평균_대비"] == 1:
            if book_df.loc[i, "서적/문구"] >= book_df.loc[i, "동월_평균_등락률"]:   # 원래 평균적으로 높은 월이라서 동월 평균보다 높으면 무조건 1
                book_df.loc[i, "소비"] = 1
                
            elif book_df.loc[i, "서적/문구"] < book_df.loc[i, "동월_평균_등락률"]:
                if book_df.loc[i, "전년_동월_대비"] == 1:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                    elif book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5): 
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                            
                elif book_df.loc[i, "전년_동월_대비"] == 0:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 1
                        else: 
                            book_df.loc[i, "소비"] = 0
                    elif book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5): 
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
        
        elif book_df.loc[i, "전체_평균_대비"] == 0:
            if book_df.loc[i, "서적/문구"] >= book_df.loc[i, "동월_평균_등락률"]:   # 원래 평균적으로 높은 월이라서 동월 평균보다 높으면 무조건 1
                book_df.loc[i, "소비"] = 1
                
            elif book_df.loc[i, "서적/문구"] < book_df.loc[i, "동월_평균_등락률"]:
                if book_df.loc[i, "전년_동월_대비"] == 1:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0                            
                    elif book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5): 
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                            
                elif book_df.loc[i, "전년_동월_대비"] == 0:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 1
                        else: 
                            book_df.loc[i, "소비"] = 0
                    elif book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5): 
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                            
    elif book_df.loc[i, "월"] == "01" or book_df.loc[i, "월"] == "02" or book_df.loc[i, "월"] == "04" or\
    book_df.loc[i, "월"] == "05" or book_df.loc[i, "월"] == "06" or book_df.loc[i, "월"] == "08" or\
    book_df.loc[i, "월"] == "09" or book_df.loc[i, "월"] == "10" or book_df.loc[i, "월"] == "11":
        if book_df.loc[i, "전체_평균_대비"] == 1:
            if book_df.loc[i, "서적/문구"] >= book_df.loc[i, "동월_평균_등락률"]:
                if book_df.loc[i, "전년_동월_대비"] == 1:
                    book_df.loc[i, "소비"] = 1
                
                elif book_df.loc[i, "전년_동월_대비"] == 0:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                        
            elif book_df.loc[i, "서적/문구"] < book_df.loc[i, "동월_평균_등락률"]:
                if book_df.loc[i, "전년_동월_대비"] == 1:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                    elif book_df.loc[i, "소비자물가지수"] > book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                            
                elif book_df.loc[i, "전년_동월_대비"] == 0:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.75):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                    else:
                        book_df.loc[i, "소비"] = 0
                
        elif book_df.loc[i, "전체_평균_대비"] == 0:
            if book_df.loc[i, "서적/문구"] >= book_df.loc[i, "동월_평균_등락률"]:
                if book_df.loc[i, "전년_동월_대비"] == 1:
                    book_df.loc[i, "소비"] = 1
                
                elif book_df.loc[i, "전년_동월_대비"] == 0:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.25):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                    else:
                        book_df.loc[i, "소비"] = 0
                        
            elif book_df.loc[i, "서적/문구"] < book_df.loc[i, "동월_평균_등락률"]:    
                if book_df.loc[i, "전년_동월_대비"] == 1:
                    book_df.loc[i, "소비"] = 1
                
                elif book_df.loc[i, "전년_동월_대비"] == 0:
                    if book_df.loc[i, "소비자물가지수"] <= book_df["소비자물가지수"].quantile(q=0.75):
                        if book_df.loc[i, "소매판매지수"] >= book_df["소매판매지수"].quantile(q=0.5):
                            book_df.loc[i, "소비"] = 1
                        else:
                            book_df.loc[i, "소비"] = 0
                    else:
                        book_df.loc[i, "소비"] = 0
                
                
book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_11224\4018655648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["날짜"] = book_df["날짜"].astype(str)
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_11224\4018655648.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["소비"] = ""
#         날짜     서적/문구   소비자물가지수    소매판매지수 동월_평균_등락률 전체_평균_대비 소비  전년_동월_대비   월
# 0   201212  0.118333  0.001782  0.023590  0.166924        1  1       1.0  12
# ...

# %%
test2_df = book_df
test2_df.to_csv('./data/test2_df.csv')
