# %%
import pandas as pd

pct_df = pd.read_csv('./data/pre_corona_pct.csv')
pct_df
# Out:
#         날짜  전자상거래/통신판매      종합소매       자동차     가구/가전     의류/잡화  스포츠/오락/여가  \
# 0   201212    0.027613  0.077909  0.192904 -0.122218 -0.031449  -0.135839
# 1   201301   -0.047579 -0.109930 -0.309056 -0.006880 -0.156039  -0.113972
# 2   201302   -0.138342 -0.063111  0.037585 -0.023821 -0.068648  -0.150124
# 3   201303    0.085685  0.029723  0.223547  0.270387  0.183154   0.355010
# 4   201304    0.045225  0.052395  0.004995 -0.081842 -0.009763   0.028387
# ..     ...         ...       ...       ...       ...       ...        ...
# 80  201908   -0.035341 -0.000307 -0.016113 -0.022230 -0.078643  -0.013531
# 81  201909    0.007732  0.043247 -0.069466 -0.120368  0.053118  -0.056002
# 82  201910    0.075294 -0.049243  0.151562  0.042041  0.175382   0.176650
# 83  201911    0.054219  0.005385  0.060822  0.044813 -0.010022  -0.052854
# 84  201912    0.035942  0.036404  0.079588 -0.039294 -0.025682  -0.092145
#
#          식료품        연료     여행/교통  ...     금융/보험   소비자물가지수    소매판매지수  \
# ...

# %%
book_df = pct_df[["날짜", "서적/문구", "소비자물가지수", "소매판매지수"]]
book_df
# Out:
#         날짜     서적/문구   소비자물가지수    소매판매지수
# 0   201212  0.118333  0.001782  0.023590
# 1   201301 -0.069215  0.005999 -0.086172
# 2   201302 -0.107126  0.003343 -0.048246
# 3   201303  0.471158 -0.000924  0.078341
# 4   201304 -0.204835 -0.001388 -0.018162
# ..     ...       ...       ...       ...
# 80  201908 -0.016262  0.002400  0.009050
# 81  201909 -0.024028  0.003711  0.016143
# 82  201910 -0.033313  0.002475  0.021183
# 83  201911  0.021241 -0.005598  0.040622
# 84  201912  0.121899  0.002392  0.009967
#
# [85 rows x 4 columns]

# %%
# book_df["날짜"] = pd.to_datetime(book_df["날짜"], format='%Y%m')     # 데이터 타입 datetime으로 변경
# book_df["날짜"] = book_df["날짜"].dt.strftime('%Y%m')                 # datetime 형식 설정
# book_df.set_index("날짜", inplace=True)                              # 날짜 컬럼 인덱스 설정

# %%
# book_df[["점수", "소비"]] = "" 
# book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\2324162201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df[["점수", "소비"]] = ""
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\2324162201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df[["점수", "소비"]] = ""
#         날짜     서적/문구   소비자물가지수    소매판매지수 점수 소비
# 0   201212  0.118333  0.001782  0.023590
# 1   201301 -0.069215  0.005999 -0.086172
# 2   201302 -0.107126  0.003343 -0.048246
# ...

# %% [markdown]
# ### 레이블

# %%
# 3월에 점수 1을 준다
def month_encoding(month):
    score = ""
    if month.endswith("03") : score = 1
    else : score = 0
    return score

# %%
book_df["날짜"] = book_df["날짜"].astype(str)
book_df["점수"] = book_df["날짜"].apply(lambda x: month_encoding(x))
book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\605068124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["날짜"] = book_df["날짜"].astype(str)
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\605068124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["점수"] = book_df["날짜"].apply(lambda x: month_encoding(x))
#         날짜     서적/문구   소비자물가지수    소매판매지수  점수
# 0   201212  0.118333  0.001782  0.023590   0
# 1   201301 -0.069215  0.005999 -0.086172   0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(16,10))

sns.heatmap(book_df.corr(), annot=True)

plt.show()

# %%
book_df.describe()
# Out:
#            서적/문구    소비자물가지수     소매판매지수
# count  85.000000  85.000000  85.000000
# mean    0.015444   0.000952   0.003923
# std     0.175948   0.003223   0.051923
# min    -0.286140  -0.007443  -0.104563
# 25%    -0.080040  -0.001261  -0.034296
# 50%    -0.024028   0.001091   0.009050
# 75%     0.077957   0.002578   0.032727
# max     0.514840   0.010629   0.162325

# %%
book_df[book_df["소비"]==1]
# Out:
#         날짜     서적/문구   소비자물가지수    소매판매지수  점수 소비
# 0   201212  0.118333  0.001782  0.023590   0  1
# 3   201303  0.471158 -0.000924  0.078341   1  1
# 7   201307  0.160407  0.002146  0.022532   0  1
# 9   201309  0.014355  0.001941  0.031833   0  1
# 10  201310 -0.011677 -0.003051  0.032979   0  1
# 11  201311  0.014116 -0.000193  0.016478   0  1
# 12  201312  0.168430  0.001214  0.012158   0  1
# 17  201405 -0.021034  0.001645  0.060541   0  1
# 19  201407  0.192122  0.001464  0.020106   0  1
# 21  201409  0.020185 -0.000645  0.018085   0  1
# 23  201411  0.036877 -0.002017  0.026694   0  1
# 27  201503  0.514840  0.000095  0.067815   1  1
# 34  201510 -0.021849  0.000000  0.040117   0  1
# 36  201512  0.281181  0.002996  0.025400   0  1
# 57  201709  0.077957  0.001163  0.080948   0  1
# 59  201711  0.075560 -0.007443  0.064815   0  1
# 60  201712  0.179838  0.003606 -0.018261   0  1
# 63  201803  0.477393 -0.001052  0.114061   1  1
# 80  201908 -0.016262  0.002400  0.009050   0  1
# ...

# %%
book_df[book_df["소비"]==0]
# Out:
#         날짜     서적/문구   소비자물가지수    소매판매지수  점수 소비
# 13  201401 -0.103812  0.005374 -0.035035   0  0
# 16  201404 -0.286140  0.000648 -0.033438   0  0
# 18  201406 -0.091243 -0.001282 -0.036697   0  0
# 22  201410 -0.035319 -0.003016  0.017764   0  0
# 26  201502 -0.116567 -0.000592 -0.013800   0  0
# 29  201505 -0.046091  0.002801  0.039514   0  0
# 32  201508 -0.080040  0.001399 -0.023493   0  0
# 35  201511 -0.061074 -0.001895  0.000000   0  0
# 37  201601 -0.111393  0.001704 -0.086239   0  0
# 40  201604 -0.284409  0.001887 -0.022967   0  0
# 44  201608 -0.085173  0.002578 -0.012733   0  0
# 46  201610 -0.023686  0.001371  0.060665   0  0
# 49  201701 -0.140694  0.010629 -0.071043   0  0
# 53  201705 -0.035323  0.001067  0.035611   0  0
# 58  201710 -0.167283 -0.000968 -0.013699   0  0
# 62  201802 -0.075422  0.007635 -0.034188   0  0
# 64  201804 -0.277346  0.001823 -0.030009   0  0
# 66  201806 -0.052572 -0.002021 -0.036348   0  0
# 74  201902 -0.106819  0.004318 -0.091075   0  0
# ...

# %%
book_df[book_df["소비"]==""]
# Out:
#         날짜     서적/문구   소비자물가지수    소매판매지수  점수 소비
# 1   201301 -0.069215  0.005999 -0.086172   0
# 2   201302 -0.107126  0.003343 -0.048246   0
# 4   201304 -0.204835 -0.001388 -0.018162   0
# 5   201305 -0.104216  0.000000  0.052231   0
# 6   201306 -0.079599 -0.001217 -0.036194   0
# 8   201308 -0.088365  0.003541 -0.044071   0
# 14  201402 -0.081359  0.002667 -0.100622   0
# 15  201403  0.459274  0.001841  0.103806   1
# 20  201408 -0.068261  0.001748 -0.024896   0
# 24  201412  0.142098 -0.000096  0.052000   0
# 25  201501 -0.075154  0.006776 -0.104563   0
# 28  201504 -0.262698  0.000307 -0.005040   0
# 30  201506 -0.090228  0.000200 -0.074074   0
# 31  201507  0.190268  0.001802  0.030526   0
# 33  201509  0.016307 -0.002594  0.069038   0
# 38  201602 -0.075779  0.004284 -0.040161   0
# 39  201603  0.455817 -0.002583  0.093096   1
# 41  201605 -0.030636  0.000596  0.050930   0
# 42  201606 -0.033689 -0.000199 -0.036347   0
# 43  201607  0.145196 -0.001883 -0.012573   0
# ...

# %%
import numpy as np

book_df["날짜"] = book_df["날짜"].astype(str)
book_df["소비"] = ""

for i in range(0, 13):
    for j in range(12, 85):
        if book_df["서적/문구"].loc[i] > 0: 
            if book_df.loc[i,"소비자물가지수"] <= 0.001091: 
                if book_df.loc[i,"소매판매지수"] >= 0.009050:
                    book_df.loc[i,"소비"] = 1
            elif book_df.loc[i,"소비자물가지수"] > 0.001091:
                if book_df.loc[i,"소매판매지수"] >= 0.009050:
                    book_df.loc[i,"소비"] = 1
            elif book_df.loc[i,"소비자물가지수"] > 0.001091:
                if book_df.loc[i,"소매판매지수"] < 0.009050:
                    book_df.loc[i,"소비"] = 0 
        elif book_df.loc[i, "서적/문구"] > -0.024028:
            if book_df.loc[i,"소비자물가지수"] <= np.mean(book_df["소비자물가지수"]): 
                if book_df.loc[i,"소매판매지수"] >= np.mean(book_df["소매판매지수"]):
                    book_df.loc[i,"소비"] = 1
            elif book_df.loc[i,"소비자물가지수"] > np.mean(book_df["소비자물가지수"]):
                if book_df.loc[i,"소매판매지수"] >= np.mean(book_df["소매판매지수"]):
                    book_df.loc[i,"소비"] = 1
            elif book_df.loc[i,"소비자물가지수"] > np.mean(book_df["소비자물가지수"]):
                if book_df.loc[i,"소매판매지수"] < np.mean(book_df["소매판매지수"]):    
                    book_df.loc[i,"소비"] = 0 
        
        # if book_df.loc[i,"점수"]==1:
        elif book_df["서적/문구"].loc[j] > 0:
            if book_df["서적/문구"].loc[j-12] > 0:
                if book_df["서적/문구"].loc[j] > book_df["서적/문구"].loc[j-12]:
                    book_df.loc[j,"소비"] = 1
                elif book_df["서적/문구"].loc[j] < book_df["서적/문구"].loc[j-12]:
                    if (book_df["서적/문구"].loc[j]) > (book_df["서적/문구"].loc[j-12]/(1/2)):                        
                        if book_df.loc[j,"소비자물가지수"] <= 0.001091: 
                            if book_df.loc[j,"소매판매지수"] >= -0.003923:
                                book_df.loc[j,"소비"] = 1
                        elif book_df.loc[j,"소비자물가지수"] > 0.001091:
                            if book_df.loc[j,"소매판매지수"] >= 0.009050:
                                book_df.loc[j,"소비"] = 1
                        elif book_df.loc[j,"소비자물가지수"] > 0.001091:
                            if book_df.loc[j,"소매판매지수"] < 0.009050:
                                book_df.loc[j,"소비"] = 0 
                    
        # elif book_df.loc[i,"점수"]==0:
        elif book_df["서적/문구"].loc[j] <= 0:
            if book_df["서적/문구"].loc[j] > book_df["서적/문구"].loc[j-12]:
                if book_df.loc[j, "서적/문구"] > -0.024028:
                    if book_df.loc[j,"소비자물가지수"] <= np.mean(book_df["소비자물가지수"]): 
                        if book_df.loc[j,"소매판매지수"] >= np.mean(book_df["소매판매지수"]):
                            book_df.loc[j,"소비"] = 1
                    elif book_df.loc[j,"소비자물가지수"] > np.mean(book_df["소비자물가지수"]):
                        if book_df.loc[j,"소매판매지수"] >= np.mean(book_df["소매판매지수"]):
                            book_df.loc[j,"소비"] = 1
                    elif book_df.loc[j,"소비자물가지수"] > np.mean(book_df["소비자물가지수"]):
                        if book_df.loc[j,"소매판매지수"] < np.mean(book_df["소매판매지수"]):    
                            book_df.loc[j,"소비"] = 0
            elif book_df["서적/문구"].loc[j] < book_df["서적/문구"].loc[j-12]:
                 book_df.loc[j,"소비"] = 0
book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\89763525.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["날짜"] = book_df["날짜"].astype(str)
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\89763525.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["소비"] = ""
#         날짜     서적/문구   소비자물가지수    소매판매지수  점수 소비
# 0   201212  0.118333  0.001782  0.023590   0  1
# 1   201301 -0.069215  0.005999 -0.086172   0
# 2   201302 -0.107126  0.003343 -0.048246   0
# ...

# %%
import numpy as np

book_df["날짜"] = book_df["날짜"].astype(str)
book_df["소비"] = ""

for i in book_df.index:
    # 양수는 일단 1을 준다
    (book_df["서적/문구"].loc[12] > 0)
    (book_df["서적/문구"].loc[12-12] > 0)
    # 전년 동월보다 크고
    (book_df["서적/문구"].loc[12] > book_df["서적/문구"].loc[12-12])
    # 전년 동월보다 작아도 양수이고 전년 동월값의 50% 이상이면? 
    (book_df["서적/문구"].loc[12] < book_df["서적/문구"].loc[12-12])
    (book_df["서적/문구"].loc[12] > book_df["서적/문구"].loc[12-12])/(1/2) 


    # 음수지만 작년 동월보다 높고
    (book_df["서적/문구"].loc[12] <= 0) 
    (book_df["서적/문구"].loc[12] > book_df["서적/문구"].loc[12-12])

    # 작년 동월보다 낮으면 0
    (book_df["서적/문구"].loc[12] < book_df["서적/문구"].loc[12-12])
    
    
    if book_df.loc[i,"점수"]==1:
        if book_df.loc[i,"소비자물가지수"] <= 0.001091: 
            if book_df.loc[i,"소매판매지수"] >= 0.009050:
                book_df.loc[i,"소비"] = 1
        elif book_df.loc[i,"소비자물가지수"] > 0.001091:
            if book_df.loc[i,"소매판매지수"] >= 0.009050:
                book_df.loc[i,"소비"] = 1
        elif book_df.loc[i,"소비자물가지수"] > 0.001091:
            if book_df.loc[i,"소매판매지수"] < 0.009050:
                book_df.loc[i,"소비"] = 0 
                
    elif book_df.loc[i,"점수"]==0:
        if book_df.loc[i, "서적/문구"] > -0.024028:
            if book_df.loc[i,"소비자물가지수"] <= np.mean(book_df["소비자물가지수"]): 
                if book_df.loc[i,"소매판매지수"] >= np.mean(book_df["소매판매지수"]):
                    book_df.loc[i,"소비"] = 1
            elif book_df.loc[i,"소비자물가지수"] > np.mean(book_df["소비자물가지수"]):
                if book_df.loc[i,"소매판매지수"] >= np.mean(book_df["소매판매지수"]):
                    book_df.loc[i,"소비"] = 1
            elif book_df.loc[i,"소비자물가지수"] > np.mean(book_df["소비자물가지수"]):
                if book_df.loc[i,"소매판매지수"] < np.mean(book_df["소매판매지수"]):    
                    book_df.loc[i,"소비"] = 0 
    # else:
    #     book_df.loc[i,"소비"] = 0
book_df
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\247393732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["날짜"] = book_df["날짜"].astype(str)
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_18192\247393732.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_df["소비"] = ""
#         날짜     서적/문구   소비자물가지수    소매판매지수  점수 소비
# 0   201212  0.118333  0.001782  0.023590   0  1
# 1   201301 -0.069215  0.005999 -0.086172   0
# 2   201302 -0.107126  0.003343 -0.048246   0
# ...

# %%
pd.set_option('display.max_row', None)
book_df
# Out:
#         날짜     서적/문구   소비자물가지수    소매판매지수  점수 소비
# 0   201212  0.118333  0.001782  0.023590   0  1
# 1   201301 -0.069215  0.005999 -0.086172   0
# 2   201302 -0.107126  0.003343 -0.048246   0
# 3   201303  0.471158 -0.000924  0.078341   1  1
# 4   201304 -0.204835 -0.001388 -0.018162   0  1
# 5   201305 -0.104216  0.000000  0.052231   0  1
# 6   201306 -0.079599 -0.001217 -0.036194   0
# 7   201307  0.160407  0.002146  0.022532   0  1
# 8   201308 -0.088365  0.003541 -0.044071   0
# 9   201309  0.014355  0.001941  0.031833   0  1
# 10  201310 -0.011677 -0.003051  0.032979   0  1
# 11  201311  0.014116 -0.000193  0.016478   0  1
# 12  201312  0.168430  0.001214  0.012158   0  1
# 13  201401 -0.103812  0.005374 -0.035035   0
# 14  201402 -0.081359  0.002667 -0.100622   0
# 15  201403  0.459274  0.001841  0.103806   1  1
# 16  201404 -0.286140  0.000648 -0.033438   0  1
# 17  201405 -0.021034  0.001645  0.060541   0  1
# 18  201406 -0.091243 -0.001282 -0.036697   0
# ...

# %%
col_list = []
col_list.append([col for col in book_df])
# Out:
# [['날짜', '서적/문구', '소비자물가지수', '소매판매지수', '소비']]

# %%
for i in col_list:
    for j in i:
        if
# Out:
# ['날짜', '서적/문구', '소비자물가지수', '소매판매지수', '소비']

# %%
pd.reset_option('display.max_rows', None)

# %%
book_df
# Out:
#         날짜     서적/문구   소비자물가지수    소매판매지수 소비
# 0   201212  0.118333  0.001782  0.023590
# 1   201301 -0.069215  0.005999 -0.086172
# 2   201302 -0.107126  0.003343 -0.048246
# 3   201303  0.471158 -0.000924  0.078341
# 4   201304 -0.204835 -0.001388 -0.018162
# 5   201305 -0.104216  0.000000  0.052231
# 6   201306 -0.079599 -0.001217 -0.036194
# 7   201307  0.160407  0.002146  0.022532
# 8   201308 -0.088365  0.003541 -0.044071
# 9   201309  0.014355  0.001941  0.031833
# 10  201310 -0.011677 -0.003051  0.032979
# 11  201311  0.014116 -0.000193  0.016478
# 12  201312  0.168430  0.001214  0.012158
# 13  201401 -0.103812  0.005374 -0.035035
# 14  201402 -0.081359  0.002667 -0.100622
# 15  201403  0.459274  0.001841  0.103806
# 16  201404 -0.286140  0.000648 -0.033438
# 17  201405 -0.021034  0.001645  0.060541
# 18  201406 -0.091243 -0.001282 -0.036697
# 19  201407  0.192122  0.001464  0.020106
# 20  201408 -0.068261  0.001748 -0.024896
# 21  201409  0.020185 -0.000645  0.018085
# ...
