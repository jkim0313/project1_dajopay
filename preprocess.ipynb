# %%
import pandas as pd

# csv파일 불러오기
df = pd.read_csv('./data/온라인쇼핑몰_취급상품범위별_상품군별거래액_20220804175111.csv', encoding='CP949')

df.head()
# Out:
#             시점        합계      합계.1     합계.2 컴퓨터 및 주변기기 컴퓨터 및 주변기기.1  \
# 0           시점         계       종합몰      전문몰          계          종합몰
# 1      2018.01   9027008   5934657  3092351     511674       354076
# 2      2018.02   8207296   5468657  2738639     453408       322160
# 3      2018.03   9375766   6269973  3105793     504061       346880
# 4      2018.04   9034274   6039799  2994475     409054       278377
# 5      2018.05   9363224   6268453  3094771     404235       276853
# 6      2018.06   8965075   6011523  2953552     371844       256035
# 7      2018.07   9653420   6494362  3159058     404250       281841
# 8      2018.08   9270381   6107050  3163331     418905       288936
# 9      2018.09   9137279   6108059  3029220     382179       267238
# 10     2018.10  10016442   6754249  3262193     419744       281410
# 11     2018.11  10574144   7150467  3423677     468166       328515
# 12     2018.12  10689701   7124412  3565289     501362       340479
# ...

# %%
# 불필요 인덱스 제거

df = df.loc[1:]

# %%
# 인덱스 재정렬

df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         시점       합계     합계.1     합계.2 컴퓨터 및 주변기기 컴퓨터 및 주변기기.1 컴퓨터 및 주변기기.2  \
# 0  2018.01  9027008  5934657  3092351     511674       354076       157598
# 1  2018.02  8207296  5468657  2738639     453408       322160       131248
# 2  2018.03  9375766  6269973  3105793     504061       346880       157181
# 3  2018.04  9034274  6039799  2994475     409054       278377       130677
# 4  2018.05  9363224  6268453  3094771     404235       276853       127382
#
#   가전·전자·통신기기 가전·전자·통신기기.1 가전·전자·통신기기.2  ... e쿠폰서비스.2   음식서비스 음식서비스.1 음식서비스.2  \
# 0     858256       770198        88058  ...     4902  347457    3120  344337
# 1     770401       691681        78720  ...     5754  324245    2764  321481
# 2     946627       839705       106922  ...     4756  361763    4286  357477
# 3     945259       855166        90093  ...     4376  365956    3706  362250
# 4    1026133       931725        94408  ...     5305  389395    4092  385303
#
#    기타서비스 기타서비스.1 기타서비스.2      기타    기타.1   기타.2
# ...

# %%
# 데이터 타입 및 결측치 유무 확인

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 73 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   시점             54 non-null     object
#  1   합계             54 non-null     object
#  2   합계.1           54 non-null     object
#  3   합계.2           54 non-null     object
#  4   컴퓨터 및 주변기기     54 non-null     object
#  5   컴퓨터 및 주변기기.1   54 non-null     object
#  6   컴퓨터 및 주변기기.2   54 non-null     object
#  7   가전·전자·통신기기     54 non-null     object
#  8   가전·전자·통신기기.1   54 non-null     object
#  9   가전·전자·통신기기.2   54 non-null     object
#  10  서적             54 non-null     object
#  11  서적.1           54 non-null     object
#  12  서적.2           54 non-null     object
#  13  사무·문구          54 non-null     object
#  14  사무·문구.1        54 non-null     object
#  15  사무·문구.2        54 non-null     object
#  16  의복             54 non-null     object
# ...

# %%
# 컬럼명 확인

df.columns
# Out:
# Index(['시점', '합계', '합계.1', '합계.2', '컴퓨터 및 주변기기', '컴퓨터 및 주변기기.1',
#        '컴퓨터 및 주변기기.2', '가전·전자·통신기기', '가전·전자·통신기기.1', '가전·전자·통신기기.2', '서적',
#        '서적.1', '서적.2', '사무·문구', '사무·문구.1', '사무·문구.2', '의복', '의복.1', '의복.2',
#        '신발', '신발.1', '신발.2', '가방', '가방.1', '가방.2', '패션용품 및 액세서리',
#        '패션용품 및 액세서리.1', '패션용품 및 액세서리.2', '스포츠·레저용품', '스포츠·레저용품.1',
#        '스포츠·레저용품.2', '화장품', '화장품.1', '화장품.2', '아동·유아용품', '아동·유아용품.1',
#        '아동·유아용품.2', '음·식료품', '음·식료품.1', '음·식료품.2', '농축수산물', '농축수산물.1',
#        '농축수산물.2', '생활용품', '생활용품.1', '생활용품.2', '자동차 및 자동차용품', '자동차 및 자동차용품.1',
#        '자동차 및 자동차용품.2', '가구', '가구.1', '가구.2', '애완용품', '애완용품.1', '애완용품.2',
#        '여행 및 교통서비스', '여행 및 교통서비스.1', '여행 및 교통서비스.2', '문화 및 레저서비스',
#        '문화 및 레저서비스.1', '문화 및 레저서비스.2', 'e쿠폰서비스', 'e쿠폰서비스.1', 'e쿠폰서비스.2',
#        '음식서비스', '음식서비스.1', '음식서비스.2', '기타서비스', '기타서비스.1', '기타서비스.2', '기타',
#        '기타.1', '기타.2'],
#       dtype='object')

# %%
# 컬럼명 변경

df.columns = df.columns.str.replace(".1", " 종합몰")
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\3273727254.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace(".1", " 종합몰")

# %%
# 컬럼명 변경

df.columns = df.columns.str.replace(".2", " 전문몰")
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\3445407488.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace(".2", " 전문몰")

# %%
# 컬럼명 변겅

df.columns = df.columns.str.replace("·", " ")

# %%
# 컬럼명 변경 확인

df.columns
# Out:
# Index(['시점', '합계', '합계 종합몰', '합계 전문몰', '컴퓨터 및 주변기기', '컴퓨터 및 주변기기 종합몰',
#        '컴퓨터 및 주변기기 전문몰', '가전 전자 통신기기', '가전 전자 통신기기 종합몰', '가전 전자 통신기기 전문몰',
#        '서적', '서적 종합몰', '서적 전문몰', '사무 문구', '사무 문구 종합몰', '사무 문구 전문몰', '의복',
#        '의복 종합몰', '의복 전문몰', '신발', '신발 종합몰', '신발 전문몰', '가방', '가방 종합몰', '가방 전문몰',
#        '패션용품 및 액세서리', '패션용품 및 액세서리 종합몰', '패션용품 및 액세서리 전문몰', '스포츠 레저용품',
#        '스포츠 레저용품 종합몰', '스포츠 레저용품 전문몰', '화장품', '화장품 종합몰', '화장품 전문몰', '아동 유아용품',
#        '아동 유아용품 종합몰', '아동 유아용품 전문몰', '음 식료품', '음 식료품 종합몰', '음 식료품 전문몰',
#        '농축수산물', '농축수산물 종합몰', '농축수산물 전문몰', '생활용품', '생활용품 종합몰', '생활용품 전문몰',
#        '자동차 및 자동차용품', '자동차 및 자동차용품 종합몰', '자동차 및 자동차용품 전문몰', '가구', '가구 종합몰',
#        '가구 전문몰', '애완용품', '애완용품 종합몰', '애완용품 전문몰', '여행 및 교통서비스',
#        '여행 및 교통서비스 종합몰', '여행 및 교통서비스 전문몰', '문화 및 레저서비스', '문화 및 레저서비스 종합몰',
#        '문화 및 레저서비스 전문몰', 'e쿠폰서비스', 'e쿠폰서비스 종합몰', 'e쿠폰서비스 전문몰', '음식서비스',
#        '음식서비스 종합몰', '음식서비스 전문몰', '기타서비스', '기타서비스 종합몰', '기타서비스 전문몰', '기타',
# ...

# %%
# 시점 컬럼 컬럼명 변경

df.rename(columns={"시점" : "날짜"}, inplace = True)
df.head(1)
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\1628150912.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"시점" : "날짜"}, inplace = True)
#         날짜       합계   합계 종합몰   합계 전문몰 컴퓨터 및 주변기기 컴퓨터 및 주변기기 종합몰  \
# 0  2018.01  9027008  5934657  3092351     511674         354076
#
#   컴퓨터 및 주변기기 전문몰 가전 전자 통신기기 가전 전자 통신기기 종합몰 가전 전자 통신기기 전문몰  ... e쿠폰서비스 전문몰  \
# 0         157598     858256         770198          88058  ...       4902
#
#     음식서비스 음식서비스 종합몰 음식서비스 전문몰  기타서비스 기타서비스 종합몰 기타서비스 전문몰      기타  기타 종합몰  \
# 0  347457      3120    344337  73143     28555     44588  227959  184708
#
#   기타 전문몰
# 0  43251
#
# [1 rows x 73 columns]

# %%
# 날짜 컬럼 '.' 제거

df["날짜"] = df["날짜"].str.replace(".", "")
df["날짜"] = df["날짜"].str.replace(" p\)", "")
df.head(1)
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\1563028464.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["날짜"] = df["날짜"].str.replace(".", "")
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\1563028464.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["날짜"] = df["날짜"].str.replace(".", "")
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\1563028464.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["날짜"] = df["날짜"].str.replace(" p\)", "")
# ...

# %%
df["날짜"] = pd.to_datetime(df["날짜"], format='%Y%m')
df["날짜"] = df["날짜"].dt.strftime('%Y-%m')
df.set_index("날짜", inplace=True)
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\3277385941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["날짜"] = pd.to_datetime(df["날짜"], format='%Y%m')
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\3277385941.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["날짜"] = df["날짜"].dt.strftime('%Y-%m')

# %%
# 날짜 컬럼을 제외한 나머지 컬럼 데이터 타입 int로 변환

df.iloc[:, 1:] = df.iloc[:, 1:].astype(int)
df.info()
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\3846439052.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[:, 1:] = df.iloc[:, 1:].astype(int)
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, 2018-01 to 2022-06
# Data columns (total 72 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   합계               54 non-null     object
#  1   합계 종합몰           54 non-null     object
#  2   합계 전문몰           54 non-null     object
#  3   컴퓨터 및 주변기기       54 non-null     object
#  4   컴퓨터 및 주변기기 종합몰   54 non-null     object
#  5   컴퓨터 및 주변기기 전문몰   54 non-null     object
#  6   가전 전자 통신기기       54 non-null     object
#  7   가전 전자 통신기기 종합몰   54 non-null     object
#  8   가전 전자 통신기기 전문몰   54 non-null     object
# ...

# %%
# 특정 단어를 포함하는 컬럼 제거

df = df[df.columns.drop(df.filter(regex="종합몰"))]
df = df[df.columns.drop(df.filter(regex="전문몰"))]
df.head(1)
# Out:
#               합계 컴퓨터 및 주변기기 가전 전자 통신기기      서적  사무 문구      의복      신발      가방  \
# 날짜
# 2018-01  9027008     511674     858256  171254  72870  964236  131568  186542
#
#         패션용품 및 액세서리 스포츠 레저용품  ...    생활용품 자동차 및 자동차용품      가구   애완용품  \
# 날짜                            ...
# 2018-01      195299   230779  ...  710430       77220  251892  72178
#
#         여행 및 교통서비스 문화 및 레저서비스  e쿠폰서비스   음식서비스  기타서비스      기타
# 날짜
# 2018-01    1491434     182387  105594  347457  73143  227959
#
# [1 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['합계', '컴퓨터 및 주변기기', '가전 전자 통신기기', '서적', '사무 문구', '의복', '신발', '가방',
#        '패션용품 및 액세서리', '스포츠 레저용품', '화장품', '아동 유아용품', '음 식료품', '농축수산물', '생활용품',
#        '자동차 및 자동차용품', '가구', '애완용품', '여행 및 교통서비스', '문화 및 레저서비스', 'e쿠폰서비스',
#        '음식서비스', '기타서비스', '기타'],
#       dtype='object')

# %%
df_food = df["음 식료품"]

df_food.head()
# Out:
# 날짜
# 2018-01    846822
# 2018-02    814658
# 2018-03    826873
# 2018-04    810015
# 2018-05    849044
# Name: 음 식료품, dtype: object

# %%
cpi_df = pd.read_csv('./data/소비자물가지수_2020100__20220803183830.csv', encoding='CP949')
cpi_df
# Out:
#          시점       전국
# 0   2018.01   98.106
# 1   2018.02   98.855
# 2   2018.03   98.751
# 3   2018.04   98.931
# 4   2018.05   98.979
# 5   2018.06   98.779
# 6   2018.07   98.590
# 7   2018.08   99.462
# 8   2018.09  100.221
# 9   2018.10  100.041
# 10  2018.11   99.330
# 11  2018.12   98.988
# 12  2019.01   98.884
# 13  2019.02   99.311
# 14  2019.03   99.121
# 15  2019.04   99.481
# 16  2019.05   99.652
# 17  2019.06   99.491
# 18  2019.07   99.187
# 19  2019.08   99.425
# 20  2019.09   99.794
# 21  2019.10  100.041
# 22  2019.11   99.481
# 23  2019.12   99.719
# 24  2020.01  100.090
# 25  2020.02  100.160
# 26  2020.03   99.940
# 27  2020.04   99.500
# 28  2020.05   99.440
# 29  2020.06   99.710
# 30  2020.07   99.630
# 31  2020.08  100.190
# 32  2020.09  100.740
# 33  2020.10  100.180
# 34  2020.11  100.090
# 35  2020.12  100.330
# 36  2021.01  101.040
# 37  2021.02  101.580
# 38  2021.03  101.840
# 39  2021.04  101.980
# 40  2021.05  102.050
# 41  2021.06  102.050
# ...

# %%
cpi_df = cpi_df.iloc[:-1]
cpi_df.head(2)
# Out:
#          시점       전국
# 0   2018.01   98.106
# 1   2018.02   98.855
# 2   2018.03   98.751
# 3   2018.04   98.931
# 4   2018.05   98.979
# 5   2018.06   98.779
# 6   2018.07   98.590
# 7   2018.08   99.462
# 8   2018.09  100.221
# 9   2018.10  100.041
# 10  2018.11   99.330
# 11  2018.12   98.988
# 12  2019.01   98.884
# 13  2019.02   99.311
# 14  2019.03   99.121
# 15  2019.04   99.481
# 16  2019.05   99.652
# 17  2019.06   99.491
# 18  2019.07   99.187
# 19  2019.08   99.425
# 20  2019.09   99.794
# 21  2019.10  100.041
# 22  2019.11   99.481
# 23  2019.12   99.719
# 24  2020.01  100.090
# 25  2020.02  100.160
# 26  2020.03   99.940
# 27  2020.04   99.500
# 28  2020.05   99.440
# 29  2020.06   99.710
# 30  2020.07   99.630
# 31  2020.08  100.190
# 32  2020.09  100.740
# 33  2020.10  100.180
# 34  2020.11  100.090
# 35  2020.12  100.330
# 36  2021.01  101.040
# 37  2021.02  101.580
# 38  2021.03  101.840
# 39  2021.04  101.980
# 40  2021.05  102.050
# 41  2021.06  102.050
# ...

# %%
cpi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      54 non-null     float64
#  1   전국      54 non-null     float64
# dtypes: float64(2)
# memory usage: 992.0 bytes

# %%
cpi_df["시점"] = cpi_df["시점"].astype(str)
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\2254366417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df["시점"] = cpi_df["시점"].astype(str)

# %%
# .10 이 .1로 변환된 걸 다시 재변환

cpi_df["시점"][cpi_df["시점"].str.endswith(".1")] = cpi_df["시점"][cpi_df["시점"].str.endswith(".1")]+"0"
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\608439360.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df["시점"][cpi_df["시점"].str.endswith(".1")] = cpi_df["시점"][cpi_df["시점"].str.endswith(".1")]+"0"

# %%
cpi_df.head(2)
# Out:
#          시점       전국
# 0   2018.01   98.106
# 1   2018.02   98.855
# 2   2018.03   98.751
# 3   2018.04   98.931
# 4   2018.05   98.979
# 5   2018.06   98.779
# 6   2018.07   98.590
# 7   2018.08   99.462
# 8   2018.09  100.221
# 9   2018.10  100.041
# 10  2018.11   99.330
# 11  2018.12   98.988
# 12  2019.01   98.884
# 13  2019.02   99.311
# 14  2019.03   99.121
# 15  2019.04   99.481
# 16  2019.05   99.652
# 17  2019.06   99.491
# 18  2019.07   99.187
# 19  2019.08   99.425
# 20  2019.09   99.794
# 21  2019.10  100.041
# 22  2019.11   99.481
# 23  2019.12   99.719
# 24  2020.01  100.090
# 25  2020.02  100.160
# 26  2020.03   99.940
# 27  2020.04   99.500
# 28  2020.05   99.440
# 29  2020.06   99.710
# 30  2020.07   99.630
# 31  2020.08  100.190
# 32  2020.09  100.740
# 33  2020.10  100.180
# 34  2020.11  100.090
# 35  2020.12  100.330
# 36  2021.01  101.040
# 37  2021.02  101.580
# 38  2021.03  101.840
# 39  2021.04  101.980
# 40  2021.05  102.050
# 41  2021.06  102.050
# ...

# %%
# 날짜로 형변환 후 인덱스로 설정

cpi_df["시점"] = pd.to_datetime(cpi_df["시점"], format="%Y.%m")
cpi_df["시점"] = cpi_df["시점"].dt.strftime('%Y-%m')
cpi_df.set_index("시점", inplace=True)
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\17190376.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df["시점"] = pd.to_datetime(cpi_df["시점"], format="%Y.%m")
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\17190376.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df["시점"] = cpi_df["시점"].dt.strftime('%Y-%m')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"


plt.subplots(figsize=(12, 10), constrained_layout=True)
plt.subplot(2, 1, 1)
plt.title("음 식료품")
plt.plot(df_food, c='b', label='음 식료품')
plt.legend()
plt.xticks(rotation=90) 
plt.grid(True)  

plt.subplot(2, 1, 2)
plt.title("소비자 물가 지수")
plt.plot(cpi_df, c='r', label='CPI')
plt.legend()
plt.xticks(rotation=90)         # 텍스트 90도 회전
plt.grid(True)                  # 그리드 표시

plt.show()

# %%
df.plot(kind='bar', figsize=(12,10), stacked=True)
plt.show()

# %%
df_food_service = df[["음 식료품", "농축수산물", "e쿠폰서비스", "음식서비스"]]
df_food_service.head()
# Out:
#           음 식료품   농축수산물  e쿠폰서비스   음식서비스
# 날짜
# 2018-01  846822  251910  105594  347457
# 2018-02  814658  289778  129231  324245
# 2018-03  826873  228800  139594  361763
# 2018-04  810015  215400  133138  365956
# 2018-05  849044  221735  169050  389395

# %%
df_food_service["음 식료품 등락률"] = df_food_service["음 식료품"].pct_change()
df_food_service.head()
# Out:
# C:\Users\wndgj\AppData\Local\Temp\ipykernel_1660\2053883080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food_service["음 식료품 등락률"] = df_food_service["음 식료품"].pct_change()
#           음 식료품   농축수산물  e쿠폰서비스   음식서비스  음 식료품 등락률
# 날짜
# 2018-01  846822  251910  105594  347457        NaN
# 2018-02  814658  289778  129231  324245  -0.037982
# 2018-03  826873  228800  139594  361763   0.014994
# 2018-04  810015  215400  133138  365956  -0.020388
# 2018-05  849044  221735  169050  389395   0.048183

# %%
plt.plot(df_food_service["음 식료품 등락률"])
plt.show()

# %%
df_food_service_cpi = pd.merge(df_food_service, cpi_df, how="left", left_index=True, right_index=True)
df_food_service_cpi.head()
# Out:
#           음 식료품   농축수산물  e쿠폰서비스   음식서비스  음 식료품 등락률      전국
# 날짜
# 2018-01  846822  251910  105594  347457        NaN  98.106
# 2018-02  814658  289778  129231  324245  -0.037982  98.855
# 2018-03  826873  228800  139594  361763   0.014994  98.751
# 2018-04  810015  215400  133138  365956  -0.020388  98.931
# 2018-05  849044  221735  169050  389395   0.048183  98.979

# %%
df_food_service_cpi.reset_index(inplace=True)
df_food_service_cpi.head()
# Out:
#         날짜   음 식료품   농축수산물  e쿠폰서비스   음식서비스  음 식료품 등락률      전국
# 0  2018-01  846822  251910  105594  347457        NaN  98.106
# 1  2018-02  814658  289778  129231  324245  -0.037982  98.855
# 2  2018-03  826873  228800  139594  361763   0.014994  98.751
# 3  2018-04  810015  215400  133138  365956  -0.020388  98.931
# 4  2018-05  849044  221735  169050  389395   0.048183  98.979

# %%
df_food_service_cpi[["음 식료품", "농축수산물", "e쿠폰서비스", "음식서비스"]] = df_food_service_cpi[["음 식료품", "농축수산물", "e쿠폰서비스", "음식서비스"]].astype(float)

# %%
df_food_service_cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   날짜         54 non-null     object
#  1   음 식료품      54 non-null     float64
#  2   농축수산물      54 non-null     float64
#  3   e쿠폰서비스     54 non-null     float64
#  4   음식서비스      54 non-null     float64
#  5   음 식료품 등락률  53 non-null     float64
#  6   전국         54 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.1+ KB

# %%
plt.figure(figsize=(12,10))

plt.plot(df_food_service_cpi["음 식료품"], color="r")
plt.plot(df_food_service_cpi["농축수산물"], color="y")
plt.plot(df_food_service_cpi["e쿠폰서비스"], color="b")
plt.plot(df_food_service_cpi["음식서비스"], color="g")
plt.plot(df_food_service_cpi["전국"], color="m")
plt.show()

# %%
x.shape
# Out:
# (54,)

# %%
y1.shape
# Out:
# (54, 4)

# %%
y2.shape
# Out:
# (54,)

# %%
fig, ax1 = plt.subplots(figsize=(12,10))
plt.xticks(rotation=90)

x = df_food_service_cpi["날짜"]
y1 = df_food_service_cpi["음 식료품"]
y2 = df_food_service_cpi["전국"]

ax1.bar(x, y1, label="음 식료품")
ax1.set_ylabel("온라인 소비 동향")
plt.legend(loc="upper left")  

ax2 = ax1.twinx()
ax2.plot(x, y2, 'o-', color="y", label="CPI")
ax2.set_ylabel("소비자 물가 지수")

plt.legend(loc="upper right")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,10))
plt.xticks(rotation=90)

y1 = df_food_service_cpi["음 식료품"]
y2 = df_food_service_cpi["전국"]

ax = df_food_service_cpi[["날짜", "음 식료품", "농축수산물", "e쿠폰서비스", "음식서비스"]].plot(x="날짜", kind="bar", stacked=True)
df_food_service_cpi[["날짜", "전국"]].plot(x="날짜", y="전국", marker='o', color='y',  ax=ax)
plt.show()

# %%
df_food_service.plot(kind='bar', figsize=(12,10))
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(12,10), constrained_layout=True)

ax1 = df_food_service["음 식료품"].plot(kind='bar', ax=axes[0,0], color="r")
ax1.set_title("음 식료품")

ax2 = df_food_service["농축수산물"].plot(kind='bar', ax=axes[0,1], color="y")
ax2.set_title("농축수산물")

ax3 = df_food_service["e쿠폰서비스"].plot(kind='bar', ax=axes[1,0], color="b")
ax3.set_title("e쿠폰서비스")

ax4 = df_food_service["음식서비스"].plot(kind='bar', ax=axes[1,1], color="g")
ax4.set_title("음식서비스")

ax5 = cpi_df["전국"].plot(kind="line", ax=axes[2,0])
ax5.set_title("CPI")
# Out:
# Text(0.5, 1.0, 'CPI')

# %%
df_car_pet = df[["자동차 및 자동차용품", "애완용품"]]
df_car_pet.head()
# Out:
#         자동차 및 자동차용품   애완용품
# 날짜
# 2018-01       77220  72178
# 2018-02       65502  60944
# 2018-03       83898  68634
# 2018-04       82601  70338
# 2018-05       84011  69233
